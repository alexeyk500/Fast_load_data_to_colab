# %%
# Загрузка необходимых библиотек и модулей

import zipfile # Библиотека для работы с zip архивами
import os      # Библиотека для работы с фаловой системой 
import time    # Библиотека для работы со временем

from google.colab import drive # Модуль для работы с Google Disk
from PIL import Image          # Модуль Image для работы с изображениями

# %%
# Подключаем гугл диск
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Прописываем путь к файлу с архивом
zip_file = '/content/drive/My Drive/Базы/Airplanes.zip'  

# Распаковываем архив
z = zipfile.ZipFile(zip_file, 'r')
z.extractall()

# Просмотр результата разархивации
print(os.listdir())
# Out:
# ['.config', 'drive', 'Airplanes', 'sample_data']

# %%
# Функция измеряющая скорость чтения файлов из каталога
def get_time_read(dir_read):
  cur_time = time.time()          # Засекаем текущее время
  num = 0                         # Количество прочитанных файлов
  list_dir = os.listdir(dir_read) # Получаем список подкаталогов
  print(list_dir)                  
  for cur_dir in list_dir:
    list_file = os.listdir(dir_read + '/' + cur_dir)
    for cur_file in list_file:
      img = Image.open(dir_read + '/' + cur_dir + '/' + cur_file) # Читаем изображение
      num += 1
  print('Количество загруженных изображений =', num)
  print('Затрачено времени -', round(time.time() - cur_time, 2), 'cек')

# %% [markdown]
# ### Проверка скорости загрузки из разархивированного каталога с Базой картинок

# %%
# Указываем путь к разархивированной базе
zip_directory = 'Airplanes'        

# Считываем все картинки из базы и считаем затраченное время
get_time_read(zip_directory)
# Out:
# ['Самолeты', 'Сегментация']
# Количество загруженных изображений = 2010
# Затрачено времени - 0.96 cек

# %% [markdown]
# ### Проверка скорости прямой загрузки из каталога Google Disc с Базой картинок

# %%
# Переключаемся на обычный Google Disc
os.chdir("/content/drive/My Drive/")

# Прописываем путь к базе
usual_dir = './Базы/Airplanes/'
os.listdir(usual_dir)

# Считываем все картинки из базы и считаем затраченное время
get_time_read(usual_dir)
# Out:
# ['Самолeты', 'Сегментация']
# Количество загруженных изображений = 2020
# Затрачено времени - 1499.64 cек
